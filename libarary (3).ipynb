# %%
class Lib:
    def _init_(self):
        self.lib=[]
        self.s=set()
        self.dict=dict()
        self.book=()
    def add_book(self,title,author,genre):
        self.book=(title,author,genre)
        print(self.book)

    def add_to_lib(self,book):
        if book not in self.s:
            self.lib.append(self.book)
            self.s.add(self.book)
            print(self.lib)
        else:
            print(f"Book Exists:{book}")
    def remove_book(self,title):
        for book in self.lib:
            if book[0]==title:
                self.lib.remove(book)
                self.s.remove(book)
                print("Book has removed")
                print(self.lib)
            else:
                print("Book not found") 
    def search_book(self,term):
        for book in self.lib:
            if book[0]==term or book[1]==term:
                print(f"Book found:{book}")
            else:
                print("Book not found")
    def list_book(self):
        if not self.lib:
            print("No book in library")
        else:
            print(self.lib)      
    def categorize_book(self):
        self.dict={}
        for book in self.dict:
            if book[2] not in self.s.key():
                self.s[book[2]]=[]
                self.dict[book[2]].append(book)
                print("Categorized books:")
            else :
                print("Unorganized")
l=Lib()
book1=0
x = True
while (x==True):
    print("---Library Management System---")
    print("1.Add a book")
    print("2.Add to library")
    print("3.Remove a book")
    print("4.Search for a book")
    print("5.List all Book")
    print("6.Categorize Book")
    print("7.Exit")
    ch=int(input("Enter a number to perform a task"))
    if ch==1:
        title=input("Enter title of the book")
        author =input("Enter the name of author")
        genre =input("Enter genre")
        book1=l.add_book(title,author,genre)
    elif ch==2:
        l.add_to_lib(book1)
    elif ch==3:
        title= input("Enter the title of the book")
        l.remove_book(title)
    elif ch==4:
        title= input("Enter the title or author of the book")
        l.search_book(title)
    elif ch==5:
        l.list_book()
    elif ch==6:
        l.categorize_book()
    elif ch==7:
        print("Exit ")
        x = False
    else:
        print("Wrong input")
